# %% [markdown]
# <a href="https://colab.research.google.com/github/25223182-hub/web/blob/main/my_website_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <!doctype html>
# <html lang="ja">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>わたしのページ</title>
# <link rel="stylesheet" href="style.css">
# </head>
# <body>
# <h1>わたしのポートフォリオ</h1>
# <p>はじめまして昭和女子大学3年のまひです</p>
# </body>
# </html>
# Out:
# <!doctype html>
# <html lang="ja">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>わたしのページ</title>
# <link rel="stylesheet" href="style.css">
# </head>
# <body>
# <h1>わたしのポートフォリオ</h1>
# <p>はじめまして昭和女子大学3年のまひです</p>
# </body>
# </html>

# %%
# %%html
# <!doctype html>
# <html lang="ja">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>わたしのページ</title>
# </head>
# <body>
#   <h1>わたしのポートフォリオ</h1>
#   <p>はじめまして昭和女子大学3年のまひです</p>
#
# <p>
#   好きなサイト
#   <a href="https://www.swu.ac.jp/" target="_blank">SWU</a>
# </p>
#
# <a href="https://www.seventeen-17.jp" target="_blank">Seventeen</a>
# <br>
# <img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">
#
# <h2>好きなこと</h2>
# <ul>
#   <li>海外旅行</li>
#   <li>散歩</li>
#   <li>美術館や博物館巡り</li>
# </ul>
# </body>
# </html>
#
# <style>
# body {
#   font-family: sans-serif;
#   line-height: 1.7;
#   color: #222;
# }
#
# h1 {
#   color: #1a3d7c;
# }
#
# h2 {
#   margin-top: 0;
# }
#
# .intro {
#   background: #f2f6ff;
# }
#
# img {
#   display: block;
# }
#
# a {
#   color: #1a3d7c;
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# .small {
#   color: #666;
# }
# </style>
# Out:
# <!doctype html>
# <html lang="ja">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>わたしのページ</title>
# </head>
# <body>
#   <h1>わたしのポートフォリオ</h1>
#   <p>はじめまして昭和女子大学3年のまひです</p>
#
# <p>
#   好きなサイト
#   <a href="https://www.swu.ac.jp/" target="_blank">SWU</a>
# </p>
#
# <a href="https://www.seventeen-17.jp" target="_blank">Seventeen</a>
# <br>
# <img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">
#
# <h2>好きなこと</h2>
# <ul>
#   <li>海外旅行</li>
#   <li>散歩</li>
#   <li>美術館や博物館巡り</li>
# </ul>
# </body>
# </html>
#
# <style>
# body {
#   font-family: sans-serif;
#   line-height: 1.7;
#   color: #222;
# }
#
# h1 {
#   color: #1a3d7c;
# }
#
# h2 {
#   margin-top: 0;
# }
#
# .intro {
#   background: #f2f6ff;
# }
#
# img {
#   display: block;
# }
#
# a {
#   color: #1a3d7c;
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# .small {
#   color: #666;
# }
# </style>

# %%
<!doctype html>
<html lang="ja">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>わたしのページ</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <h1>わたしのポートフォリオ</h1>
  <p>はじめまして昭和女子大学3年のまひです</p>
</body>
</html>

<p>
  好きなサイト
  <a href="https://www.swu.ac.jp/" target="_blank">SWU</a>
</p>

https://www.seventeen-17.jp
<img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">

<h2>好きなこと</h2>
<ul>
  <li>海外旅行</li>
  <li>散歩</li>
  <li>美術館や博物館巡り</li>
</ul>

body {
  font-family: sans-serif;
  line-height: 1.7;
  color: #222;
}

h1 {
  color: #1a3d7c;
}

h2 {
  margin-top: 0;
}

.intro {
  background: #f2f6ff;
}

section {
}

img {
  display: block;
}

a {
  color: #1a3d7c;
  text-decoration: none;
}

a:hover {
  text-decoration: underline;
}

.small {
  color: #666;
}

# %%
<!doctype html>
<html lang="ja">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>わたしのページ</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <h1>わたしのポートフォリオ</h1>
  <p>はじめまして昭和女子大学3年のまひです</p>
</body>
</html>

<p>
  好きなサイト
  <a href="https://www.swu.ac.jp/" target="_blank">SWU</a>
</p>
https://www.seventeen-17.jp
<img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">

<h2>好きなこと</h2>
<ul>
  <li>海外旅行</li>
  <li>散歩</li>
  <li>美術館や博物館巡り</li>
</ul>

body {
  font-family: sans-serif;
  line-height: 1.7;
  color: #222;
}

h1 {
  color: #1a3d7c;
}

h2 {
  margin-top: 0;
}

.intro {
  background: #f2f6ff;
}

section {
}

img {
  display: block;
}

a {
  color: #1a3d7c;
  text-decoration: none;
}

a:hover {
  text-decoration: underline;
}

.small {
  color: #666;
}

# %%
<!doctype html>
<html lang="ja">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>わたしのページ</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <h1>わたしのポートフォリオ</h1>
  <p>はじめまして昭和女子大学3年のまひです</p>
</body>
</html>

<p>
  好きなサイト
  <a href="https://www.seventeen-17.jp" target="_blank">SVT</a>
</p>
<img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">

<h2>好きなこと</h2>
<ul>
  <li>海外旅行</li>
  <li>散歩</li>
  <li>美術館や博物館巡り</li>
</ul>

body {
  font-family: sans-serif;
  line-height: 1.7;
  color: #222;
}

h1 {
  color: #1a3d7c;
}

h2 {
  margin-top: 0;
}

.intro {
  background: #f2f6ff;
}

section {
}

img {
  display: block;
}

a {
  color: #1a3d7c;
  text-decoration: none;
}

a:hover {
  text-decoration: underline;
}

.small {
  color: #666;
}

# %%
<!doctype html>
<html lang="ja">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>わたしのページ</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <h1>わたしのポートフォリオ</h1>
  <p>はじめまして昭和女子大学3年のまひです</p>
</body>
</html>

<p>
  好きなサイト
  <a href="https://www.swu.ac.jp/" target="_blank">SWU</a>
</p>

<img src="images/IMG_0179.HEIC" alt="自己紹介の写真" width="240">

<h2>好きなこと</h2>
<ul>
  <li>海外旅行</li>
  <li>散歩</li>
  <li>美術館や博物館巡り</li>
</ul>

body {
  font-family: sans-serif;
  line-height: 1.7;
  color: #222;
}

h1 {
  color: #1a3d7c;
}

h2 {
  margin-top: 0;
}

.intro {
  background: #f2f6ff;
}

section {
}

img {
  display: block;
}

a {
  color: #1a3d7c;
  text-decoration: none;
}

a:hover {
  text-decoration: underline;
}

.small {
  color: #666;
}
